# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshSharma16/ML-Engineer-Roadmap/blob/main/data_and_schema_validation_with_gx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===============================
# GX VALIDATION FOR sales.csv
# ===============================

# !pip install -q great-expectations
# !pip install -q pandera
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5225576a-8854-4452-9975-0ed75ab6fb64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5225576a-8854-4452-9975-0ed75ab6fb64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Define schema
schema = pa.DataFrameSchema({
    "Order ID": Column(int, nullable=False, unique=True),
    "Units Sold": Column(int, Check.ge(0)),
    "Unit Price": Column(float, Check.ge(0)),
    "Unit Cost": Column(float, Check.ge(0)),
    "Sales Channel": Column(str, Check.isin(["Online", "Offline"])),
    "Order Priority": Column(str, Check.isin(["H", "M", "L", "C"]))
})

# Validate
try:
    schema.validate(df)
    print("✅ Validation success: True")
except pa.errors.SchemaError as e:
    print("❌ Validation success: False")
    print(e)
# Out:
# ✅ Validation success: True
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df.loc[0, "Sales Channel"] = "Invalid"
schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /tmp/ipython-input-737295839.py in <cell line: 0>()
#       1 df.loc[0, "Sales Channel"] = "Invalid"
# ----> 2 schema.validate(df)
#
# /usr/local/lib/python3.12/dist-packages/pandera/api/pandas/container.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     115             return check_obj.pandera.add_schema(self)
#     116
# --> 117         return self._validate(
#     118             check_obj=check_obj,
#     119             head=head,
#
# /usr/local/lib/python3.12/dist-packages/pandera/api/pandas/container.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     135         inplace: bool = False,
#     136     ) -> pd.DataFrame:
# --> 137         return self.get_backend(check_obj).validate(
#     138             check_obj,
#     139             schema=self,
#
# ...
